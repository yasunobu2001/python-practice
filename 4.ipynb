# %% [markdown]
# <a href="https://colab.research.google.com/github/yasunobu2001/python-practice/blob/main/4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count = 0
while count < 3:
    count += 1
    print(f"ひつじが{count}匹")
print("おやすみなさい")
# Out:
# ひつじが1匹
# ひつじが2匹
# ひつじが3匹
# おやすみなさい

# %%
is_awake = True
count = 0
while is_awake == True:
    count += 1
    print(f"ひつじが{count}匹")
    key = input("もう眠りそうですか？(y/n) >>")
    if key == "y":
        is_awake = False
print("おやすみなさい")
# Out:
# ひつじが1匹
# もう眠りそうですか？(y/n) >>n
# ひつじが2匹
# もう眠りそうですか？(y/n) >>n
# ひつじが3匹
# もう眠りそうですか？(y/n) >>n
# ひつじが4匹
# もう眠りそうですか？(y/n) >>y
# おやすみなさい

# %%
is_awake = True
count = 0

# ポイント1: 「== True」は省略してシンプルに書くのがPython流です
while is_awake:
    count += 1
    print(f'ひつじが{count}匹')
    key = input('もう眠りそうですか?(y/n) >> ')

    # ポイント2: 大文字の「Y」が入力された場合にも対応させると親切です
    if key.lower() == 'y':
        is_awake = False

print('おやすみなさい')
# Out:
# ひつじが1匹
# もう眠りそうですか?(y/n) >> n
# ひつじが2匹
# もう眠りそうですか?(y/n) >> n
# ひつじが3匹
# もう眠りそうですか?(y/n) >> y
# おやすみなさい

# %%
count = 0
student_num = int(input("学生の数を入力>>"))
score_list = list()
while count < student_num:
    count += 1
    score = int(input(f"{count}人目の試験の得点を入力　>>"))
    score_list.append(score)
print(score_list)
total = sum(score_list)
print(F"平均点は{total / student_num}点です")
# Out:
# 学生の数を入力>>3
# 1人目の試験の得点を入力　>>50
# 2人目の試験の得点を入力　>>60
# 3人目の試験の得点を入力　>>70
# [50, 60, 70]
# 平均点は60.0点です

# %%
scores = [80,20,75,60]
count = 0
while count < len(scores):
    if scores[count] >= 60:
        print("合格")
    else:
        print("不合格")
    count += 1
# Out:
# 合格
# 不合格
# 合格
# 合格

# %%
scores = [80,20,75,60]
for date in scores:
    if date >= 60:
        print("合格")
    else:
        print("不合格")
# Out:
# 合格
# 不合格
# 合格
# 合格

# %%
ages = [28,50,8,20,78,25,22,10,27,33]
num = 5     # 目標の抽出数
samples = list()
for date in ages:
    if 20 <= date < 30:
        samples.append(date)
        if len(samples) == num:
            break
print(samples)
# Out:
# [28, 20, 25, 22, 27]

# %%
ages = [28,50,8,20,78,25,22,10,27,33]
num = 5     # 目標の抽出数
 # リスト内包表記（抽出条件まで）
samples = [data for data in ages if 20 <= data < 30][:num] #スライス n未満の要素
print(samples)
# Out:
# [28, 20, 25, 22, 27]

# %%
ages = [28,50,"ひみつ",20,78,25,22,10,"無回答",33]
samples = list()
for data in ages:
    if not isinstance(data,int): #整数でないデータはスキップ
        continue
    if data < 20 or data >= 30:  #目的の条件に合致しないデータはスキップ
        continue
    samples.append(data)
print(samples)
# Out:
# [28, 20, 25, 22]

# %%
ages = [28, 50, "ひみつ", 20, 78, 25, 22, 10, "無回答", 33]

# 内包表記：数値であること(isinstance) かつ 20代であること(20 <= d < 30)
samples = [data for data in ages if isinstance(data, int) and 20 <= data < 30]

print(samples)
# Out:
# [28, 20, 25, 22]
